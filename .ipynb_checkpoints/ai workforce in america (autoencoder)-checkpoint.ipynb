# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

from src.app import Transformer

from sklearn.decomposition import PCA

from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# # get the dataset from data folder in src

# %%
dataset_location = "src/data/ai_job_market.csv"

df = pd.read_csv(dataset_location)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_id            2000 non-null   int64
#  1   company_name      2000 non-null   object
#  2   industry          2000 non-null   object
#  3   job_title         2000 non-null   object
#  4   skills_required   2000 non-null   object
#  5   experience_level  2000 non-null   object
#  6   employment_type   2000 non-null   object
#  7   location          2000 non-null   object
#  8   salary_range_usd  2000 non-null   object
#  9   posted_date       2000 non-null   object
#  10  company_size      2000 non-null   object
#  11  tools_preferred   2000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 187.6+ KB

# %%
df.head(5)
# Out:
#    job_id              company_name    industry                 job_title  \
# 0       1           Foster and Sons  Healthcare              Data Analyst
# 1       2   Boyd, Myers and Ramirez        Tech  Computer Vision Engineer
# 2       3                  King Inc        Tech          Quant Researcher
# 3       4  Cooper, Archer and Lynch        Tech        AI Product Manager
# 4       5                  Hall LLC     Finance            Data Scientist
#
#                                      skills_required experience_level  \
# 0  NumPy, Reinforcement Learning, PyTorch, Scikit...              Mid
# 1                    Scikit-learn, CUDA, SQL, Pandas           Senior
# 2          MLflow, FastAPI, Azure, PyTorch, SQL, GCP            Entry
# 3       Scikit-learn, C++, Pandas, LangChain, AWS, R              Mid
# 4                    Excel, Keras, SQL, Hugging Face           Senior
#
#   employment_type               location salary_range_usd posted_date  \
# 0       Full-time          Tracybury, AR     92860-109598  2025-08-20
# 1       Full-time         Lake Scott, CU     78523-144875  2024-03-22
# 2       Full-time         East Paige, CM    124496-217204  2025-09-18
# 3       Full-time          Perezview, FI     50908-123743  2024-05-08
# 4        Contract  North Desireeland, NE     98694-135413  2025-02-24
#
#   company_size                  tools_preferred
# 0        Large                  KDB+, LangChain
# 1        Large        FastAPI, KDB+, TensorFlow
# 2        Large  BigQuery, PyTorch, Scikit-learn
# 3        Large     TensorFlow, BigQuery, MLflow
# 4        Large               PyTorch, LangChain

# %% [markdown]
# # custom one hot encoder

# %%
def OneHotEncoders_for_multiple_data(x):
    set_container = set()
    
    #this is for adding a 
    def adder(x=[]):
        for i in x:
            #too much hassle, so i just make a condition
            if(i[0] == ' '):
                i = i[1:]
            set_container.add(i)
    
    seperator = lambda x: str.split(x, sep=",")
    
    x = x.map(arg=seperator)
    
    x.map(adder)
    
    template = dict(zip(set_container,[0 for i in range(len(set_container))]))
    
    result_container = []
    
    def initiated_counter(x):
        initiated = template.copy()
        for i in x:
            #too much hassle, so i just make a condition
            if(i[0] == ' '):
                i = i[1:]
            if(i in initiated):
                initiated[i] += 1
        return list(initiated.values())
    
    x.map(arg=(
        lambda x: result_container.append(
            initiated_counter(x)
        )
    ))
    
    return pd.DataFrame(result_container, columns=list(set_container))

# %%
#seperate the data into each variable
skill_required = df["skills_required"].copy()
skill_required = OneHotEncoders_for_multiple_data(skill_required)

tools_preferred = df["tools_preferred"].copy()
tools_preferred = OneHotEncoders_for_multiple_data(tools_preferred)

industry = df["industry"].copy()
industry = OneHotEncoders_for_multiple_data(industry)

job_title = df["job_title"].copy()
job_title = OneHotEncoders_for_multiple_data(job_title)

# %%
#for this data, we want to seperate the data first, so we then we can have mean
#of the salary
salary_range_usd = df["salary_range_usd"].copy()
salary_range_usd = pd.DataFrame(pd.DataFrame(salary_range_usd.map(
    arg=lambda x: [int(i) for i in str.split(x, sep="-")]
).to_list()).mean(axis=1), columns=["mean_salary_range"])

# %%
salary_range_usd
# Out:
#       mean_salary_range
# 0              101229.0
# 1              111699.0
# 2              170850.0
# 3               87325.5
# 4              117053.5
# ...                 ...
# 1995           100254.0
# 1996            92521.5
# 1997           157551.0
# 1998            72463.5
# 1999            76604.5
#
# [2000 rows x 1 columns]

# %% [markdown]
# # make a dictionary for 3 feature (experience_level, company_size, employment_type)
#
# those feature would only be used as filter for the jobs later, it wont get calculated
# on the model

# %%
used_df = df.copy()

#because experience level has hirarchy (Entry level obliviously below mid, etc)
#so the treatment for this data is label encoding
experience_level_hirarchy = {"Entry":0, "Mid":1, "Senior":2}

#its also same for company size
company_size_hirarchy = {'Startup':0, 'Mid':1, 'Large':2}

#same
#this hirarchy is based on preferability
employment_type_hirarchy = {'Internship':0,'Contract':1, 'Full-time':2, 'Remote':3}

#replace the experience_level feature to df
used_df["experience_level"] = used_df["experience_level"].map(experience_level_hirarchy)

#also do it for company_size_hirarchy
used_df["company_size"] = used_df["company_size"].map(company_size_hirarchy)

#same
used_df["employment_type"] = used_df["employment_type"].map(employment_type_hirarchy)

# %%
#we change the posted_date feature to datetime type for convinient
used_df["posted_date"] = pd.to_datetime(used_df["posted_date"], format="%Y-%m-%d")

# %%
#dropped because we want to do seperate things for these data, so we drop it first
dropped_columns = [
    "skills_required", "tools_preferred", "industry", 
    "job_title", "salary_range_usd", 
    "company_name", "location", "posted_date", "job_id"]

used_df.drop(columns=dropped_columns, inplace=True)

# %% [markdown]
# # combine all of the feature we process into one dataframe

# %%
def combine_dataframe(base=pd.DataFrame([]), combined=pd.DataFrame([]), axis=1):
    return pd.concat([base,combined],axis=axis)

list_data = [skill_required, tools_preferred, industry, job_title]

for i in list_data:
    used_df = combine_dataframe(used_df, i)

used_df = combine_dataframe(used_df, salary_range_usd)

# %% [markdown]
# # scalling the data
#
# in this case, we would rescale the data before we do PCA and Autoencoder process
#
# we would use 3 type of feature scalling, StandardScaler, MinMaxScaler, and RobustScaler

# %%
#as we use employment_type, experience_level, and company_size as a filter, those data
#would get excluded from the dataframe

dropped_columns = ["employment_type", "company_size", "experience_level"]

standard_scaler = StandardScaler()
standardscaler_result = standard_scaler.fit_transform(used_df.drop(columns=dropped_columns))

minmax_scaler = MinMaxScaler(feature_range=(0,1))
minmaxscaler_result = minmax_scaler.fit_transform(used_df.drop(columns=dropped_columns))

robust_scaler = RobustScaler()
robustscaler_result = robust_scaler.fit_transform(used_df.drop(columns=dropped_columns))

# %% [markdown]
# # PCA and Autoencoder All Data
#
# we want to found which is the best method to reduce dimensionality of processed data

# %% [markdown]
# # PCA to All data
#
# we start with the uncomplicated one, pca

# %%
#make PCA for each processed scaller
#we reduce it to 4 components
n_components = 4

pca_standardscaler_result = PCA(n_components).fit_transform(standardscaler_result)

pca_minmaxscaler_result = PCA(n_components).fit_transform(minmaxscaler_result)

pca_robustscaler_result = PCA(n_components).fit_transform(robustscaler_result)

# %% [markdown]
# # Autoencoder to Dataframe
#
# next we go to the complicated one, autoencoder to the dataframe

# %%
#its already been made in src/app folder, for the detail look at it

#hidden layer is based on reduction for each step, so because dimension is 47, its go from 
#47 -> 32 -> 16 -> 8 -> 4
hidden_layer =  [32 ,16, 8]
loss = ""
epoch = 5
to_shape = 4

# %%
#for standard scaler result

test = standardscaler_result

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3892 - val_loss: 0.3742
# Epoch 2/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3687 - val_loss: 0.3680
# Epoch 3/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3685 - val_loss: 0.3665
# Epoch 4/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3668 - val_loss: 0.3655
# Epoch 5/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3646 - val_loss: 0.3643
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
autoencoder.check_performance(test)
# Out:
# <tf.Tensor: shape=(2000, 48), dtype=float32, numpy=
# array([[-0.10768168,  0.09436773, -0.1269896 , ..., -0.11590747,
#         -0.12960632,  0.17673393],
#        [ 0.04915039, -0.21553549, -0.18369669, ..., -0.18205   ,
#         -0.26991773, -0.2720933 ],
#        [-0.24631917,  0.15674095, -0.07217905, ..., -0.21070695,
#         -0.20309025,  0.43845537],
#        ...,
#        [-0.32503325,  0.17240307, -0.06103047, ..., -0.27542356,
#         -0.25315338,  0.6009801 ],
#        [ 0.09130898, -0.24617511, -0.21601027, ..., -0.1950076 ,
#         -0.24162297, -0.2710648 ],
#        [ 0.17961496, -0.56005776, -0.2633156 , ..., -0.36253858,
#         -0.37539887, -0.4588531 ]], dtype=float32)>

# %%
standardscaler_result
# Out:
# array([[ 0.04415586,  1.23599281,  2.        , ...,  2.5258808 ,
#         -0.3788279 , -0.62733869],
#        [ 1.27070755,  1.23599281,  2.        , ..., -0.3959015 ,
#         -0.3788279 , -0.32619543],
#        [-1.18239583,  1.23599281, -0.5       , ..., -0.3959015 ,
#          2.6397211 ,  1.37513455],
#        ...,
#        [-1.18239583,  1.23599281,  2.        , ...,  2.5258808 ,
#         -0.3788279 ,  0.99262221],
#        [ 1.27070755,  1.23599281,  2.        , ..., -0.3959015 ,
#          2.6397211 , -1.45470606],
#        [ 1.27070755, -1.21759093, -0.5       , ..., -0.3959015 ,
#          2.6397211 , -1.3356006 ]])

# %%
#for min max scaler result

test = minmaxscaler_result

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0957 - val_loss: 0.0801
# Epoch 2/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0777 - val_loss: 0.0750
# Epoch 3/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0746 - val_loss: 0.0743
# Epoch 4/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0743 - val_loss: 0.0742
# Epoch 5/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0742 - val_loss: 0.0742
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
autoencoder.check_performance(test)
# Out:
# <tf.Tensor: shape=(2000, 48), dtype=float32, numpy=
# array([[0.61243427, 0.67525125, 0.28607503, ..., 0.19038485, 0.15400779,
#         0.6414138 ],
#        [0.5886902 , 0.6435187 , 0.27330405, ..., 0.18168148, 0.14849885,
#         0.61162055],
#        [0.56586355, 0.61301225, 0.2610265 , ..., 0.1733144 , 0.14320268,
#         0.58297837],
#        ...,
#        [0.50429374, 0.5307276 , 0.22791052, ..., 0.15074599, 0.12891759,
#         0.5057224 ],
#        [0.53599805, 0.5730986 , 0.244963  , ..., 0.16236718, 0.13627344,
#         0.545504  ],
#        [0.3226627 , 0.28997767, 0.13076779, ..., 0.08306223, 0.0880128 ,
#         0.27843052]], dtype=float32)>

# %%
minmaxscaler_result
# Out:
# array([[0.5       , 1.        , 1.        , ..., 1.        , 0.        ,
#         0.3571985 ],
#        [1.        , 1.        , 1.        , ..., 0.        , 0.        ,
#         0.42690648],
#        [0.        , 1.        , 0.        , ..., 0.        , 1.        ,
#         0.82072664],
#        ...,
#        [0.        , 1.        , 1.        , ..., 1.        , 0.        ,
#         0.73218352],
#        [1.        , 1.        , 1.        , ..., 0.        , 1.        ,
#         0.1656813 ],
#        [1.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.19325157]])

# %%
autoencoder.get_result(test)
# Out:
# <tf.Tensor: shape=(2000, 2), dtype=float32, numpy=
# array([[ 1.5483737 , -1.9014419 ],
#        [ 1.5887232 , -1.6388004 ],
#        [ 1.3998717 , -1.6496743 ],
#        ...,
#        [ 1.1999362 , -1.3209902 ],
#        [ 1.2734575 , -1.5242904 ],
#        [ 0.41149697, -0.5935821 ]], dtype=float32)>

# %%
#for robust scaler result

test = robustscaler_result

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0916 - val_loss: 0.0796
# Epoch 2/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0786 - val_loss: 0.0778
# Epoch 3/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0779 - val_loss: 0.0776
# Epoch 4/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0774 - val_loss: 0.0765
# Epoch 5/5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0761 - val_loss: 0.0759
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
autoencoder.check_performance(test)
# Out:
# <tf.Tensor: shape=(2000, 48), dtype=float32, numpy=
# array([[-0.0168631 , -0.05605721,  0.24064353, ...,  0.17000005,
#          0.12847145,  0.04579698],
#        [-0.00349537, -0.06051589,  0.20835288, ...,  0.15429378,
#          0.1541409 , -0.00100236],
#        [-0.00831678, -0.05272102,  0.19432503, ...,  0.1444663 ,
#          0.14483295, -0.00500142],
#        ...,
#        [-0.04221911,  0.01394869,  0.28468353, ...,  0.16715337,
#          0.05212198,  0.09356047],
#        [-0.0361358 , -0.04737682,  0.12745562, ...,  0.10120132,
#          0.15046257, -0.08637041],
#        [-0.04986488,  0.01423931,  0.19908191, ...,  0.1215613 ,
#          0.04782107,  0.07451472]], dtype=float32)>

# %%
robustscaler_result
# Out:
# array([[ 0.        ,  0.5       ,  1.        , ...,  1.        ,
#          0.        , -0.38586486],
#        [ 0.5       ,  0.5       ,  1.        , ...,  0.        ,
#          0.        , -0.20200889],
#        [-0.5       ,  0.5       ,  0.        , ...,  0.        ,
#          1.        ,  0.83669832],
#        ...,
#        [-0.5       ,  0.5       ,  1.        , ...,  1.        ,
#          0.        ,  0.60316436],
#        [ 0.5       ,  0.5       ,  1.        , ...,  0.        ,
#          1.        , -0.89099466],
#        [ 0.5       , -0.5       ,  0.        , ...,  0.        ,
#          1.        , -0.8182776 ]])

# %%
intership_data = used_df[used_df["employment_type"] == 0].copy().drop("employment_type", axis=1)

contract_data = used_df[used_df["employment_type"] == 1].copy().drop("employment_type", axis=1)

full_time_data = used_df[used_df["employment_type"] == 2].copy().drop("employment_type", axis=1)

remote_data = used_df[used_df["employment_type"] == 3].copy().drop("employment_type", axis=1)

employment_datas = [intership_data, contract_data, full_time_data, remote_data]

index_data_list = []

minmax_scaler = MinMaxScaler(feature_range=(0,1))

minmax_scaler.fit(used_df.copy().drop("employment_type", axis=1))
# Out:
# MinMaxScaler()

# %% [markdown]
# # check kmeans performance on each partial dataset

# %%
from src.report import ElbowMethod

# %%
test = minmax_scaler.transform(intership_data)

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0967 - val_loss: 0.0952
# Epoch 2/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0928 - val_loss: 0.0892
# Epoch 3/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0866 - val_loss: 0.0837
# Epoch 4/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0803 - val_loss: 0.0794
# Epoch 5/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0761 - val_loss: 0.0768
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
ElbowMethod.report(
    autoencoder.get_result(minmax_scaler.transform(intership_data))
)

# %%
test = minmax_scaler_list[0].transform(contract_data)

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0987 - val_loss: 0.0979
# Epoch 2/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0936 - val_loss: 0.0925
# Epoch 3/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0888 - val_loss: 0.0877
# Epoch 4/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0833 - val_loss: 0.0836
# Epoch 5/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0797 - val_loss: 0.0803
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
ElbowMethod.report(
    autoencoder.get_result(minmax_scaler.transform(contract_data))
)

# %%
test = minmax_scaler_list[0].transform(full_time_data)

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.1016 - val_loss: 0.0973
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0961 - val_loss: 0.0939
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0935 - val_loss: 0.0899
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0887 - val_loss: 0.0852
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0839 - val_loss: 0.0808
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
ElbowMethod.report(
    autoencoder.get_result(minmax_scaler.transform(full_time_data))
)

# %%
test = minmax_scaler_list[0].transform(remote_data)

autoencoder = Transformer.transform(
    test, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)
autoencoder_result = pd.DataFrame(
    autoencoder.predict(test)
)
# Out:
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0990 - val_loss: 0.0989
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0964 - val_loss: 0.0957
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0910 - val_loss: 0.0912
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0872 - val_loss: 0.0850
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0834 - val_loss: 0.0810
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
ElbowMethod.report(
    autoencoder.get_result(minmax_scaler.transform(remote_data))
)

# %% [markdown]
# # kmeans model implementation

# %%
kmeans_model = []

autoencoder_list = []

hidden_layer =  [32 ,16, 8]
loss = ""
epoch = 5
to_shape = 4

index = 0

for i in employment_datas:
    result = minmax_scaler_list[index].transform(i)
    
    autoencoder = Transformer.transform(
        result, input_shape=test.shape[1], to_shape=to_shape, hidden_layer=hidden_layer, loss=loss, epoch=epoch)

    model = KMeans(3)
    
    model.fit(
        autoencoder.get_result(result)
    )
    
    kmeans_model.append(model)
    autoencoder_list.append(autoencoder)
    index += 1
# Out:
# Epoch 1/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0980 - val_loss: 0.0955
# Epoch 2/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0928 - val_loss: 0.0888
# Epoch 3/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0858 - val_loss: 0.0820
# Epoch 4/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0795 - val_loss: 0.0772
# Epoch 5/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0755 - val_loss: 0.0750
# Epoch 1/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0994 - val_loss: 0.0989
# Epoch 2/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0950 - val_loss: 0.0947
# Epoch 3/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0908 - val_loss: 0.0881
# Epoch 4/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0849 - val_loss: 0.0830
# Epoch 5/5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0793 - val_loss: 0.0796
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1000 - val_loss: 0.0947
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0924 - val_loss: 0.0871
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0852 - val_loss: 0.0810
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0799 - val_loss: 0.0775
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0762 - val_loss: 0.0761
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0983 - val_loss: 0.0982
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0943 - val_loss: 0.0920
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0869 - val_loss: 0.0857
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0805 - val_loss: 0.0807
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0771 - val_loss: 0.0778

# %%
result = df.copy()

# %%
result_respect_to_employment_level = []

index = 0

for i in employment_datas:
    result_respect_to_employment_level.append(kmeans_model[index].predict(
        autoencoder_list[index].get_result(minmax_scaler_list[index].transform(i))
    ))
    index += 1

# %%
result_on_each_employment_level = []

employment_type_list = [i for i in employment_type_hirarchy.keys()]

index = 0

for i in result_respect_to_employment_level:
    result_on_each_employment_level.append(
        combine_dataframe(
            result[result["employment_type"] == employment_type_list[index]],
            pd.DataFrame(i, columns=["label"], index=index_data_list[index])
        , axis=1)
    )
    index += 1

# %%
import numpy as np
from scipy.spatial.distance import cdist

# %%
employment_datas[1]
# Out:
#       experience_level  company_size  FastAPI  Power BI  Scikit-learn  Python  \
# 4                    2             2        0         0             0       0
# 27                   0             0        0         0             0       1
# 29                   0             0        0         0             1       0
# 32                   1             0        1         0             0       0
# 34                   0             2        0         0             0       0
# ...                ...           ...      ...       ...           ...     ...
# 1986                 0             1        0         1             0       0
# 1991                 0             0        0         0             0       1
# 1992                 1             0        0         0             1       0
# 1997                 0             2        0         0             1       0
# 1998                 2             2        0         0             1       1
#
#       MLflow  Keras  Reinforcement Learning  SQL  ...  E-commerce  \
# 4          0      1                       0    1  ...           0
# 27         0      0                       0    0  ...           0
# 29         0      0                       0    1  ...           0
# 32         0      1                       0    0  ...           0
# 34         0      0                       0    0  ...           0
# ...      ...    ...                     ...  ...  ...         ...
# 1986       0      0                       0    1  ...           0
# 1991       1      0                       0    0  ...           0
# 1992       0      0                       0    0  ...           0
# 1997       1      0                       0    0  ...           0
# 1998       0      0                       0    0  ...           0
#
#       Data Scientist  Quant Researcher  AI Researcher  AI Product Manager  \
# 4                  1                 0              0                   0
# 27                 0                 0              0                   0
# 29                 0                 0              0                   0
# 32                 0                 0              0                   1
# 34                 0                 0              0                   0
# ...              ...               ...            ...                 ...
# 1986               1                 0              0                   0
# 1991               0                 1              0                   0
# 1992               0                 0              0                   0
# 1997               0                 0              0                   0
# 1998               0                 1              0                   0
#
#       ML Engineer  NLP Engineer  Data Analyst  Computer Vision Engineer  \
# 4               0             0             0                         0
# 27              0             0             1                         0
# 29              0             0             1                         0
# 32              0             0             0                         0
# 34              0             0             0                         1
# ...           ...           ...           ...                       ...
# 1986            0             0             0                         0
# 1991            0             0             0                         0
# 1992            0             0             0                         1
# 1997            0             0             1                         0
# 1998            0             0             0                         0
#
#       mean_salary_range
# 4              117053.5
# 27             148691.5
# 29             116250.0
# 32              80135.5
# 34             115927.0
# ...                 ...
# 1986            83509.5
# 1991           114291.0
# 1992            54933.5
# 1997           157551.0
# 1998            72463.5
#
# [465 rows x 48 columns]

# %%
result_on_each_employment_level[0]
# Out:
#       job_id              company_name    industry           job_title  \
# 7          8               Mullins Ltd   Education      Data Scientist
# 8          9               Aguilar PLC  Healthcare         ML Engineer
# 10        11             Vaughan-Ortiz        Tech      Data Scientist
# 17        18               Smith-Moore  Automotive  AI Product Manager
# 19        20                 Gates LLC  E-commerce         ML Engineer
# ...      ...                       ...         ...                 ...
# 1979    1980               Cook-Fowler     Finance  AI Product Manager
# 1987    1988   Solis, Peters and Walsh        Tech         ML Engineer
# 1989    1990    Hall, Barber and Young        Tech      Data Scientist
# 1993    1994               Moran-Brown        Tech        NLP Engineer
# 1995    1996  Mueller, Ellis and Clark     Finance        NLP Engineer
#
#                                    skills_required experience_level  \
# 7                                Excel, SQL, Flask            Entry
# 8                    Pandas, LangChain, GCP, Azure            Entry
# 10           Keras, MLflow, Reinforcement Learning            Entry
# 17    Excel, MLflow, Hugging Face, Flask, Power BI            Entry
# 19                          R, CUDA, Power BI, AWS              Mid
# ...                                            ...              ...
# 1979               FastAPI, Keras, Flask, AWS, GCP              Mid
# 1987      AWS, Azure, Python, R, Scikit-learn, GCP           Senior
# 1989     AWS, Azure, C++, LangChain, Python, Flask            Entry
# 1993                             Azure, C++, Keras           Senior
# 1995                      Flask, FastAPI, Power BI           Senior
#
#      employment_type             location salary_range_usd posted_date  \
# 7         Internship      Port Hailey, RU      63032-82144  2024-08-14
# 8         Internship      Butlermouth, GB    134239-188504  2025-09-15
# 10        Internship   New Angelatown, LU     99964-125971  2024-01-10
# 17        Internship     Blevinsburgh, VU    138184-192857  2024-04-29
# 19        Internship      Stevenhaven, BW    115578-207180  2024-08-29
# ...              ...                  ...              ...         ...
# 1979      Internship     Kevinborough, SE     72541-113000  2024-03-18
# 1987      Internship    Jennifermouth, HR     75187-168220  2024-10-12
# 1989      Internship    Williamshaven, NI    101664-150656  2025-01-09
# 1993      Internship       Brownburgh, WS    149301-234157  2025-01-08
# 1995      Internship  Washingtonmouth, SD     90382-110126  2024-04-22
#
#      company_size                    tools_preferred  label
# 7           Large                           BigQuery      2
# 8           Large  Scikit-learn, LangChain, BigQuery      2
# 10          Large  LangChain, BigQuery, Scikit-learn      1
# 17        Startup                           BigQuery      2
# 19          Large                             MLflow      2
# ...           ...                                ...    ...
# 1979          Mid                  MLflow, LangChain      2
# 1987        Large    BigQuery, TensorFlow, LangChain      1
# 1989      Startup                     KDB+, BigQuery      2
# 1993          Mid                          LangChain      2
# 1995        Large                             MLflow      0
#
# [574 rows x 13 columns]

# %%
result_on_each_employment_level[1][result_on_each_employment_level[1]["label"] == 2]
# Out:
#       job_id                    company_name    industry  \
# 51        52          Ellis, Crane and Boyle  E-commerce
# 65        66       Harris, Porter and Walter      Retail
# 86        87                      Ward-Allen   Education
# 90        91      Sawyer, Donovan and Vargas  Automotive
# 97        98  Travis, Fletcher and Rodriguez     Finance
# ...      ...                             ...         ...
# 1821    1822                 Valentine-Hodge  Healthcare
# 1824    1825                   Garza-Gilbert   Education
# 1829    1830                  Stokes-Cameron  E-commerce
# 1960    1961                   Daniels-Moore  E-commerce
# 1984    1985                    Grimes-Moore  Automotive
#
#                      job_title  \
# 51    Computer Vision Engineer
# 65               AI Researcher
# 86            Quant Researcher
# 90                NLP Engineer
# 97    Computer Vision Engineer
# ...                        ...
# 1821             AI Researcher
# 1824            Data Scientist
# 1829          Quant Researcher
# 1960            Data Scientist
# 1984              Data Analyst
#
#                                         skills_required experience_level  \
# 51    Azure, Keras, Scikit-learn, Hugging Face, Exce...            Entry
# 65    C++, Reinforcement Learning, NumPy, Azure, MLf...              Mid
# 86                                 C++, Power BI, NumPy              Mid
# 90    TensorFlow, Power BI, FastAPI, LangChain, Scik...              Mid
# 97         Python, SQL, Power BI, Scikit-learn, FastAPI              Mid
# ...                                                 ...              ...
# 1821       AWS, Scikit-learn, Keras, PyTorch, LangChain            Entry
# 1824                       R, PyTorch, SQL, NumPy, CUDA              Mid
# 1829     GCP, CUDA, PyTorch, FastAPI, TensorFlow, Excel              Mid
# 1960      NumPy, Hugging Face, C++, Power BI, LangChain              Mid
# 1984                       TensorFlow, Excel, LangChain              Mid
#
#      employment_type               location salary_range_usd posted_date  \
# 51          Contract        North Jason, MR     73140-164506  2025-05-30
# 65          Contract  Port Kristenmouth, SA    106117-199125  2023-12-19
# 86          Contract       Jeffreyburgh, SC     98118-167073  2024-09-10
# 90          Contract         Lake Erica, NL     81426-145890  2023-10-19
# 97          Contract    Port Julieburgh, KW    127896-227744  2023-12-18
# ...              ...                    ...              ...         ...
# 1821        Contract       Jasonborough, CG     64534-127901  2025-04-08
# 1824        Contract         Robertbury, HR    110008-207656  2023-11-24
# 1829        Contract         Perrymouth, BG      58077-99999  2025-04-01
# 1960        Contract    West Justinfort, AO      40402-80152  2025-04-22
# 1984        Contract       Melissamouth, VC     46246-137067  2025-05-02
#
#      company_size            tools_preferred  label
# 51            Mid   LangChain, KDB+, FastAPI      2
# 65          Large              FastAPI, KDB+      2
# 86          Large        LangChain, BigQuery      2
# 90            Mid  BigQuery, KDB+, LangChain      2
# 97          Large   FastAPI, KDB+, LangChain      2
# ...           ...                        ...    ...
# 1821        Large              KDB+, FastAPI      2
# 1824        Large                       KDB+      2
# 1829      Startup                       KDB+      2
# 1960        Large  KDB+, FastAPI, TensorFlow      2
# 1984          Mid     KDB+, FastAPI, PyTorch      2
#
# [78 rows x 13 columns]

# %%
result_on_each_employment_level[2][result_on_each_employment_level[2]["experience_level"] == "Senior"]
# Out:
#       job_id               company_name    industry                 job_title  \
# 1          2    Boyd, Myers and Ramirez        Tech  Computer Vision Engineer
# 9         10                  Parks LLC  Automotive  Computer Vision Engineer
# 13        14               Frank-Duarte      Retail          Quant Researcher
# 30        31                    Gay PLC        Tech          Quant Researcher
# 54        55            Williams-Vargas  Healthcare          Quant Researcher
# ...      ...                        ...         ...                       ...
# 1965    1966                   Chen Ltd        Tech          Quant Researcher
# 1972    1973   Miller, Russell and Reed   Education             AI Researcher
# 1978    1979  Johnson, Hughes and Smith  E-commerce        AI Product Manager
# 1983    1984                 Ball-Kelly  Automotive             AI Researcher
# 1999    2000                Estes Group     Finance          Quant Researcher
#
#                                         skills_required experience_level  \
# 1                       Scikit-learn, CUDA, SQL, Pandas           Senior
# 9             Excel, Reinforcement Learning, TensorFlow           Senior
# 13    Excel, MLflow, NumPy, Hugging Face, LangChain,...           Senior
# 30                             Keras, Excel, TensorFlow           Senior
# 54             Keras, Excel, FastAPI, Azure, R, PyTorch           Senior
# ...                                                 ...              ...
# 1965     Hugging Face, LangChain, Python, FastAPI, CUDA           Senior
# 1972    Hugging Face, LangChain, Excel, NumPy, Power BI           Senior
# 1978    Python, Power BI, MLflow, Hugging Face, FastAPI           Senior
# 1983                                    Keras, Excel, R           Senior
# 1999                        Flask, TensorFlow, Power BI           Senior
#
#      employment_type                location salary_range_usd posted_date  \
# 1          Full-time          Lake Scott, CU     78523-144875  2024-03-22
# 9          Full-time         Nicoleshire, BA     79361-165029  2025-08-07
# 13         Full-time       Christianberg, GQ    137004-193975  2024-11-20
# 30         Full-time   Port Patriciaport, TG      54565-94461  2024-06-27
# 54         Full-time            Carlland, ME    135916-233596  2024-11-10
# ...              ...                     ...              ...         ...
# 1965       Full-time      East Markville, GM    125311-197070  2025-01-27
# 1972       Full-time  East Sylviaborough, ML     74296-157397  2025-06-20
# 1978       Full-time    New Michaelmouth, NP    140375-162701  2024-11-09
# 1983       Full-time  North Melissashire, LA    126658-206526  2024-08-06
# 1999       Full-time        Benjaminview, NE      55835-97374  2025-02-20
#
#      company_size                      tools_preferred  label
# 1           Large            FastAPI, KDB+, TensorFlow      0
# 9           Large                   MLflow, TensorFlow      0
# 13            Mid  LangChain, TensorFlow, Scikit-learn      2
# 30        Startup                        KDB+, PyTorch      2
# 54        Startup        FastAPI, TensorFlow, BigQuery      2
# ...           ...                                  ...    ...
# 1965      Startup            KDB+, BigQuery, LangChain      2
# 1972          Mid         BigQuery, FastAPI, LangChain      0
# 1978        Large             TensorFlow, Scikit-learn      0
# 1983      Startup            BigQuery, MLflow, FastAPI      1
# 1999      Startup                               MLflow      0
#
# [183 rows x 13 columns]

# %%
result_on_each_employment_level[3]
# Out:
#       job_id                   company_name    industry           job_title  \
# 5          6                      Ellis PLC  E-commerce  AI Product Manager
# 14        15                     Rogers Ltd   Education        NLP Engineer
# 15        16                   Wright-Evans  Automotive        NLP Engineer
# 18        19                  Webb and Sons  Healthcare      Data Scientist
# 20        21  Whitaker, Walker and Sandoval      Retail    Quant Researcher
# ...      ...                            ...         ...                 ...
# 1974    1975       Smith, Simon and Bennett        Tech    Quant Researcher
# 1977    1978                   Tate-Burnett        Tech        Data Analyst
# 1981    1982                    Schmidt Inc  E-commerce        NLP Engineer
# 1988    1989                     Webb-Walls     Finance  AI Product Manager
# 1996    1997                     Roberts-Yu  Automotive  AI Product Manager
#
#                                         skills_required experience_level  \
# 5                      GCP, Excel, Scikit-learn, MLflow           Senior
# 14                         Pandas, CUDA, NumPy, FastAPI              Mid
# 15    Hugging Face, Scikit-learn, Reinforcement Lear...           Senior
# 18    AWS, Azure, Power BI, CUDA, Reinforcement Lear...           Senior
# 20                  C++, Power BI, R, SQL, Keras, Azure            Entry
# ...                                                 ...              ...
# 1974               CUDA, Hugging Face, GCP, Python, AWS            Entry
# 1977  LangChain, Reinforcement Learning, CUDA, Panda...           Senior
# 1981              Flask, GCP, Keras, LangChain, PyTorch           Senior
# 1988                             NumPy, R, FastAPI, SQL              Mid
# 1996           R, Flask, Excel, C++, CUDA, Scikit-learn              Mid
#
#      employment_type                location salary_range_usd posted_date  \
# 5             Remote         South Kevin, TZ     92632-180718  2025-08-07
# 14            Remote    New Katieborough, FJ    129842-216741  2024-07-08
# 15            Remote    Stephaniechester, LU    124669-217866  2024-04-06
# 18            Remote           Parkmouth, CA    100845-159745  2024-10-19
# 20            Remote        Gregorymouth, LV    122521-175168  2024-01-19
# ...              ...                     ...              ...         ...
# 1974          Remote     West Loganburgh, DJ    109031-158268  2025-08-31
# 1977          Remote       Harrischester, ER     85582-159454  2024-07-13
# 1981          Remote  South Craigchester, KG     83082-168419  2024-03-23
# 1988          Remote    Port Camerontown, BB     75937-160307  2025-02-10
# 1996          Remote          Joshuafort, ZA     47848-137195  2023-12-02
#
#      company_size                  tools_preferred  label
# 5           Large     PyTorch, TensorFlow, FastAPI      1
# 14          Large                          FastAPI      0
# 15        Startup                       TensorFlow      2
# 18            Mid          BigQuery, FastAPI, KDB+      0
# 20          Large  Scikit-learn, BigQuery, PyTorch      1
# ...           ...                              ...    ...
# 1974      Startup               FastAPI, LangChain      2
# 1977        Large                       TensorFlow      0
# 1981      Startup          Scikit-learn, LangChain      0
# 1988        Large                 KDB+, TensorFlow      1
# 1996        Large          KDB+, LangChain, MLflow      0
#
# [452 rows x 13 columns]
